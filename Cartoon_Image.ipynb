# %%
# Necessary imports
import cv2
import numpy as np
#  Importing function cv2_imshow necessary for programming in Google Colab
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("/content/images (38).jpeg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=704x436 at 0x7F099596B5D0>

# %%
edges = cv2.Canny(img, 100, 320)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=704x436 at 0x7F09958EEE50>

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
edges = cv2.adaptiveThreshold(gray, 500, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 47, 27)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=704x436 at 0x7F09958F2F10>

# %%
color = cv2.bilateralFilter(img, d=7, sigmaColor=6,sigmaSpace=9)
cv2_imshow(color)
# Out:
# <PIL.Image.Image image mode=RGB size=704x436 at 0x7F0995888C90>

# %%
def color_quantization(img, k):
# Defining input data for clustering
  data = np.float32(img).reshape((-1, 3))
# Defining criteria
  criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 200, 20.0)
# Applying cv2.kmeans function
  ret, label, center = cv2.kmeans(data, k, None, criteria, 10, cv2.KMEANS_RANDOM_CENTERS)
  center = np.uint8(center)
  result = center[label.flatten()]
  result = result.reshape(img.shape)
  return result

# %%
img_1 = color_quantization(img, 5)
cv2_imshow(img_1)

# %%
cartoon = cv2.bitwise_and(color, color, img_1, mask=edges)
cv2_imshow(cartoon)
# Out:
# <PIL.Image.Image image mode=RGB size=704x436 at 0x7F0995888390>
